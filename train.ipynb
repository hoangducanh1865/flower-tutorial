# %%
print(hello)
# Out:
# 你好黄德英！

# %%
# !git clone https://github.com/hoangducanh1865/flower-tutorial
# Out:
# Cloning into 'flower-tutorial'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 1), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 5.94 KiB | 1.98 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
'''
git config user.name 
git config user.email
git remote -v 
git branch 

git status

git add .
git commit -m “Update”
git push -u origin main 
'''

# %cd flower-tutorial
# !git pull 
# %cd ..
# Out:
# /kaggle/working/flower-tutorial
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 594 bytes | 594.00 KiB/s, done.
# From https://github.com/hoangducanh1865/flower-tutorial
#    2e92a7b..6d42e41  main       -> origin/main
# Updating 2e92a7b..6d42e41
# Fast-forward
#  get_start_with_flower.py | 405 -----------------------------------------------
#  train.ipynb              | 341 ++-------------------------------------
#  2 files changed, 14 insertions(+), 732 deletions(-)
#  delete mode 100644 get_start_with_flower.py
# /kaggle/working

# %%
# !pip install -q flwr[simulation] flwr-datasets[vision] torch torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 26.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.8 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 40.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.1/598.1 kB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 6.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.8 which is incompatible.
# ydata-profiling 4.16.1 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.10.3 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.9.0 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# dataproc-spark-connect 0.7.5 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
# !python flower-tutorial/src/flwr_server.py

# %%
# !python flower-tutorial/src/flwr_client.py

# %%
# !python src/flwr_server.py

# %%
# !python main.py
# Out:
# ^C
# Server-side evaluation loss 0.13863192801475524, accuracy 0.0001
# Server-side evaluation loss 0.13863192801475524, accuracy 0.0001
# (ClientAppActor pid=24740) [Client 0] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 2] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 9] evaluate, config: {}
# Server-side evaluation loss 0.13863192801475524, accuracy 0.0001
# (ClientAppActor pid=24740) [Client 0] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 3] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 4] evaluate, config: {}
# Server-side evaluation loss 0.13863192801475524, accuracy 0.0001
# (ClientAppActor pid=24740) [Client 0] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 1] evaluate, config: {}
# (ClientAppActor pid=24740) [Client 9] evaluate, config: {}
# INFO :      Starting Flower ServerApp, config: num_rounds=3, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 0.13863192801475524, {'accuracy': 0.0001}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# INFO :      aggregate_fit: received 0 results and 3 failures
# INFO :      fit progress: (1, 0.13863192801475524, {'accuracy': 0.0001}, 71.1266272)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 10)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     server_round = config["server_round"]
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# INFO :      aggregate_fit: received 0 results and 3 failures
# INFO :      fit progress: (2, 0.13863192801475524, {'accuracy': 0.0001}, 164.7069262)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 10)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
# ERROR :     Traceback (most recent call last):
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 187, in process_message
#     raise ex
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\server\superlink\fleet\vce\backend\raybackend.py", line 175, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 480, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 2639, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 144, in __call__
#     return self._call(message, context)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client_app.py", line 128, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\message_handler\message_handler.py", line 128, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\client.py", line 224, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\client\numpy_client.py", line 227, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "d:\MachineLearning\flower-tutorial\src\flwr_client.py", line 22, in fit
#     self.valloader = valloader
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\common\record\typeddict.py", line 50, in __getitem__
#     return cast(dict[K, V], self.__dict__["_data"])[item]
# KeyError: 'server_round'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=24740, ip=127.0.0.1, actor_id=35f93f4eaac18c4f2d8d6bed01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x000001916FCE5E20>)
#   File "python\ray\_raylet.pyx", line 1890, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1991, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1896, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1837, in ray._raylet.execute_task.function_executor
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\_private\function_manager.py", line 691, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\ray\util\tracing\tracing_helper.py", line 467, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "d:\Anaconda\envs\TMenv\lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 64, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: 'server_round'
#
# INFO :      aggregate_fit: received 0 results and 3 failures
# INFO :      fit progress: (3, 0.13863192801475524, {'accuracy': 0.0001}, 256.3416524)
# INFO :      configure_evaluate: strategy sampled 3 clients (out of 10)
# INFO :      aggregate_evaluate: received 3 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 3 round(s) in 292.38s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.14173534965515136
# INFO :      		round 2: 0.14170379002889
# INFO :      		round 3: 0.14171540307998656
# INFO :      	History (loss, centralized):
# INFO :      		round 0: 0.13863192801475524
# INFO :      		round 1: 0.13863192801475524
# INFO :      		round 2: 0.13863192801475524
# INFO :      		round 3: 0.13863192801475524
# INFO :      	History (metrics, centralized):
# INFO :      	{'accuracy': [(0, 0.0001), (1, 0.0001), (2, 0.0001), (3, 0.0001)]}
# INFO :
